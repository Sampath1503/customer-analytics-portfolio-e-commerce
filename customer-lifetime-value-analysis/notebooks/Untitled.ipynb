# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/clv_scoring_dataset.csv").head()
df
# Out:
#    CustomerID  frequency  recency    T  monetary_value  \
# 0     12346.0          1        0  326    77183.600000
# 1     12347.0          7      365  367       23.681319
# 2     12348.0          4      282  358       57.975484
# 3     12349.0          1        0   19       24.076027
# 4     12350.0          1        0  310       19.670588
#
#    predicted_purchases_6m  expected_monetary_value        clv_6m CLV Segment
# 0                0.170661             77015.259228  12696.388406  High Value
# 1                3.552782                24.128356     82.804054  High Value
# 2                2.245364                58.738529    127.399335  High Value
# 3                5.742041                27.198452    150.878518  High Value
# 4                0.192459                22.802802      4.239317   Low Value
